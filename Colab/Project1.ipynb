# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/IE643/Project
# Out:
# /content/drive/MyDrive/IE643/Project

# %%
ls
# Out:
# EfficientFormer/  EfficientFormer.zip

# %%
# !unzip EfficientFormer.zip

# %%
ls
# Out:
# EfficientFormer/  EfficientFormer.zip

# %%
cd EfficientFormer/
# Out:
# /content/drive/MyDrive/IE643/Project/EfficientFormer

# %%
ls
# Out:
#  3classData/    dist_train.sh   models/                   requirements.txt       temp.py
#  blank2.pdf     images/         my_model.py               run_with_submitit.py   toolbox.py
#  detection/     LICENSE        'Pretrained model.ipynb'   segmentation/          util/
#  dist_test.sh   main.py         README.md                 slurm_train.sh

# %%
# !pip install timm -q

# %%
# !python3 main.py --data-path ./3classData/ --distillation-type none --epochs 100
# Out:
# Not using distributed mode
# ...
